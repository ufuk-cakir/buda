# %%
from buda.analysis.instagram_accounts import query_instagram_api

api_key = "bP47R3p7eitiumWBLQocHRcKz1hfQXvr"
query_instagram_api(api_key, "yukikitterkat")
# Out:
# iwcui__
# 'Other'

# %% [markdown]
# Run the analysis on real data

# %%
from buda.utils import load_data
from buda.analysis.instagram_accounts import analyze_instagram_accounts
data = load_data("/Users/cakir/Downloads/instagram-ufukistcool-2024-11-09-Pab1sslx/your_instagram_activity/likes/liked_posts.json")

api_key = "bP47R3p7eitiumWBLQocHRcKz1hfQXvr"
output_folder="instagram_liked_content"


analyze_instagram_accounts(data, api_key, output_folder)
# Out:
# [{'title': 'onlycato', 'string_list_data': [{'href': 'https://www.instagram.com/p/DBjBLoAPyUE/', 'value': 'ð\x9f\x91\x8d', 'timestamp': 1731143482}]}, {'title': 'lofipassion', 'string_list_data': [{'href': 'https://www.instagram.com/reel/DB_ztcMvTZe/', 'value': 'ð\x9f\x91\x8d', 'timestamp': 1731105442}]}, {'title': 'wgalbers', 'string_list_data': [{'href': 'https://www.instagram.com/reel/DBeTZLnt-1L/', 'value': 'ð\x9f\x91\x8d', 'timestamp': 1731022571}]}, {'title': 'bigtimemaca', 'string_list_data': [{'href': 'https://www.instagram.com/reel/DBrJ4Kvv7Ck/', 'value': 'ð\x9f\x91\x8d', 'timestamp': 1731022465}]}, {'title': 'panchbantz', 'string_list_data': [{'href': 'https://www.instagram.com/reel/DA_nYy8oG0W/', 'value': 'ð\x9f\x91\x8d', 'timestamp': 1731022125}]}, {'title': 'lolita', 'string_list_data': [{'href': 'https://www.instagram.com/reel/DCEaIrUs3R2/', 'value': 'ð\x9f\x91\x8d', 'timestamp': 1731022078}]}, {'title': '_meldaaaa_', 'string_list_data': [{'href': 'https://www.instagram
# ...

# %%
from buda.analysis.instagram_accounts import analyze_categories
from buda.utils import load_data

stats = load_data("instagram_liked_content/categorized_data.json")
analyze_categories(stats, output_folder="../data")
# Out:
# {'Pets': 14, 'Art': 18, 'Lifestyle': 50, 'Friends': 52, 'Other': 32}
