# %%
# check whether the package is installed
from buda.analysis import analyze_likes
from buda.analysis import extract_days_of_week
from buda.utils import load_data

# Example usage
data = load_data("/Users/alexandrudobra/Downloads/instagram-alexdobra.lk76-2024-11-09-HYDpf5jx/your_instagram_activity/likes/liked_posts.json")
analyze_likes(data)

# test extract_days_of_week
extract_days_of_week(data)
# Out:
# Total number of likes: 741
# Likes by hour of day:
# 0:00 - 4 likes
# 1:00 - 1 likes
# 2:00 - 2 likes
# 3:00 - 2 likes
# 4:00 - 12 likes
# 5:00 - 72 likes
# 6:00 - 51 likes
# 7:00 - 37 likes
# 8:00 - 36 likes
# 9:00 - 39 likes
# 10:00 - 31 likes
# 11:00 - 38 likes
# 12:00 - 35 likes
# 13:00 - 33 likes
# 14:00 - 20 likes
# 15:00 - 42 likes
# 16:00 - 50 likes
# 17:00 - 49 likes
# 18:00 - 49 likes
# 19:00 - 39 likes
# 20:00 - 63 likes
# 21:00 - 18 likes
# 22:00 - 8 likes
# 23:00 - 10 likes
# [2,
#  0,
#  6,
#  2,
#  1,
#  4,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  6,
#  4,
#  5,
#  5,
#  6,
#  6,
#  6,
#  5,
#  4,
#  4,
#  3,
#  0,
#  0,
#  5,
#  4,
#  3,
#  1,
#  2,
#  5,
#  3,
#  3,
#  3,
#  6,
#  6,
#  6,
#  1,
#  6,
#  6,
#  3,
#  4,
#  6,
#  1,
#  0,
#  3,
#  2,
#  2,
#  2,
#  2,
#  2,
#  0,
#  3,
#  4,
#  5,
#  2,
#  3,
#  3,
#  0,
#  4,
#  4,
#  4,
#  2,
#  5,
#  5,
#  2,
#  5,
#  1,
#  1,
#  6,
#  3,
#  0,
#  0,
#  0,
#  0,
#  5,
#  3,
#  1,
#  4,
#  4,
# ...

# %%
from buda.analysis.likes import *
from buda.utils import load_data

# TODO make colors contrasty with the instagrammy colors
# Example usage
data = load_data("/Users/alexandrudobra/Downloads/instagram-alexdobra.lk76-2024-11-09-HYDpf5jx/your_instagram_activity/likes/liked_posts.json")
hourly_activity = get_hourly_activity(data)
week_day_activity = get_days_of_week_activity(data)

# test display_days_of_week_statistics
day_of_week_activity = display_days_of_week_statistics(data, week_day_activity)

# save this as a json
import json
with open('day_of_week_activity.json', 'w') as f:
    json.dump(day_of_week_activity, f)
# Out:
# Total number of likes: {'likes_media_likes': [{'title': 'cherdleys2', 'string_list_data': [{'href': 'https://www.instagram.com/reel/DBj1t9WgzLz/', 'value': 'ð\x9f\x91\x8d', 'timestamp': 1730307338}]}, {'title': 'alexandra.pop._', 'string_list_data': [{'href': 'https://www.instagram.com/p/DBlv0F7sfh2/', 'value': 'ð\x9f\x91\x8d', 'timestamp': 1730136905}]}, {'title': 'teodoracomsa', 'string_list_data': [{'href': 'https://www.instagram.com/p/DAN5IhqO5wg/', 'value': 'ð\x9f\x91\x8d', 'timestamp': 1727006946}]}, {'title': 'ephraimlisk_', 'string_list_data': [{'href': 'https://www.instagram.com/reel/C9lGWlwgRAt/', 'value': 'ð\x9f\x91\x8d', 'timestamp': 1726038715}]}, {'title': 'ephraimlisk_', 'string_list_data': [{'href': 'https://www.instagram.com/reel/C-bQDtnCdbu/', 'value': 'ð\x9f\x91\x8d', 'timestamp': 1725991452}]}, {'title': 'nurse.johnn', 'string_list_data': [{'href': 'https://www.instagram.com/reel/C8k9M_cvYHH/', 'value': 'ð\x9f\x91\x8d', 'timestamp': 1725621862}]}, {'title': 'andre
# ...

# %%
# test
