# %%
from buda.analysis import analyze_likes

# %%
from buda.utils import load_data

# Example usage
data = load_data("/Users/cakir/Downloads/instagram-ufukistcool-2024-11-09-Pab1sslx/your_instagram_activity/likes/liked_posts.json")
analyze_likes(data)
# Out:
# Total number of likes: 1614
# Likes by hour of day:
# 0:00 - 53 likes
# 1:00 - 40 likes
# 2:00 - 7 likes
# 3:00 - 1 likes
# 4:00 - 3 likes
# 5:00 - 8 likes
# 6:00 - 10 likes
# 7:00 - 86 likes
# 8:00 - 135 likes
# 9:00 - 169 likes
# 10:00 - 116 likes
# 11:00 - 100 likes
# 12:00 - 75 likes
# 13:00 - 56 likes
# 14:00 - 49 likes
# 15:00 - 54 likes
# 16:00 - 70 likes
# 17:00 - 74 likes
# 18:00 - 91 likes
# 19:00 - 73 likes
# 20:00 - 45 likes
# 21:00 - 61 likes
# 22:00 - 119 likes
# 23:00 - 119 likes
